# %% [markdown]
# <a href="https://colab.research.google.com/github/Joaoldc/colab-testes/blob/main/estudos_colab_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('olá mundo!')
a = 5**2

print("o valor de a é ",a)

carro_idade = 5
print('o carro tem ',carro_idade, ' anos')
# Out:
# olá mundo!
# o valor de a é  25
# o carro tem  5  anos
